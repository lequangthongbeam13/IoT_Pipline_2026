# %%
source /Users/beam/2026_spring/IoT_Pipline_2026/ML/tf-env/bin/activate

# %% [markdown]
# Activate env: source /Users/beam/2026_spring/IoT_Pipline_2026/ML/tf-env/bin/activate

# %%
import os
os.environ["PATH"] += os.pathsep + "/opt/homebrew/bin"

#for graphviz
