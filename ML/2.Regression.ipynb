# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Synthetic linear data
X = np.arange(-20, 21, 2, dtype=np.float32) # [-20, -18, ..., 20]
y = X + 10
# Train/test split (simple)
# Divide it into a Training set (for learning) and a Test set (to check if the model truly understands the rules or is just memorizing them).
X_train, y_train = X[:15], y[:15]
X_test, y_test = X[15:], y[15:]
# 1) CREATE
model = tf.keras.Sequential([
tf.keras.layers.Input(shape=(1,)),
tf.keras.layers.Dense(1) # linear output for regression
])
# 2) COMPILE
model.compile(
loss="mae",
optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
metrics=["mae"]
)
# 3) FIT
# Let the model view the data set Train repeated 200 times (epochs=200).
history = model.fit(X_train, y_train, epochs=400, verbose=0)
# Evaluate
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print("Test MAE:", mae)
# Predict and visualize
y_pred = model.predict(X_test).squeeze()
plt.figure(figsize=(6,4))
plt.scatter(X_train, y_train, c='b', label='Train')
plt.scatter(X_test, y_test, c='g', label='Test')
plt.scatter(X_test, y_pred, c='r', label='Pred')
plt.legend(); plt.title("Regression: y = x + 10 learned")
plt.show()
# Out:
# Test MAE: 14.08535385131836
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %% [markdown]
# Improve:
# - Ading layer
# - change app function
# - chnage optimizeation func
# - chnage learing rate
# - fitting more data
# - fir for longer.

# %% [markdown]
# - Try to change epoch from 400 to 500
# - add 1 more Dense layer
# - add activation relu

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Synthetic linear data
X = np.arange(-20, 21, 2, dtype=np.float32) # [-20, -18, ..., 20]
y = X + 10
# Train/test split (simple)
# Divide it into a Training set (for learning) and a Test set (to check if the model truly understands the rules or is just memorizing them).
X_train, y_train = X[:20], y[:20]
X_test, y_test = X[20:], y[20:]
# 1) CREATE
model = tf.keras.Sequential([
tf.keras.layers.Input(shape=(1,)),
tf.keras.layers.Dense(10,activation ='relu'), # linear output for regression
tf.keras.layers.Dense(1)
])
# 2) COMPILE
model.compile(
loss="mae",
# optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
metrics=["mae"]
)
# 3) FIT
# Let the model view the data set Train repeated 200 times (epochs=200).
history = model.fit(X_train, y_train, epochs=500, verbose=0)
# Evaluate
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print("Test MAE:", mae)
# Predict and visualize
y_pred = model.predict(X_test).squeeze()
plt.figure(figsize=(6,4))
plt.scatter(X_train, y_train, c='b', label='Train')
plt.scatter(X_test, y_test, c='g', label='Test')
plt.scatter(X_test, y_pred, c='r', label='Pred')
plt.legend(); plt.title("Regression: y = x + 10 learned")
plt.show()
# Out:
# Test MAE: 0.22423744201660156
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x14a3b0d60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %% [markdown]
# Try to add more test data
# change optimizer to Adam
# add value and activation

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Synthetic linear data
# X = np.arange(-20, 21, 2, dtype=np.float32) # [-20, -18, ..., 20]
X = np.linspace(-20, 20, 100, dtype=np.float32)
y = X + 10

# Chia 80% để học, 20% để kiểm tra
split_index = int(0.8 * len(X)) 
X_train, y_train = X[:split_index], y[:split_index]
X_test, y_test = X[split_index:], y[split_index:]
print (f"độ dài X: {len(X)}")
print (f"độ dài X_train: {split_index}")


# Train/test split (simple)
# Divide it into a Training set (for learning) and a Test set (to check if the model truly understands the rules or is just memorizing them).
# X_train, y_train = X[:20], y[:20]
# X_test, y_test = X[20:], y[20:]
# 1) CREATE
model = tf.keras.Sequential([
tf.keras.layers.Input(shape=(1,)),
tf.keras.layers.Dense(1) # linear output for regression
])
# 2) COMPILE
model.compile(
loss="mae",
optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
metrics=["mae"]
)
# 3) FIT
# Let the model view the data set Train repeated 200 times (epochs=200).
history = model.fit(X_train, y_train, epochs=400, verbose=0)
# Evaluate
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print("Test MAE:", mae)
# Predict and visualize
y_pred = model.predict(X_test).squeeze()
plt.figure(figsize=(6,4))
plt.scatter(X_train, y_train, c='b', label='Train')
plt.scatter(X_test, y_test, c='g', label='Test')
plt.scatter(X_test, y_pred, c='r', label='Pred')
plt.legend(); plt.title("Regression: y = x + 10 learned")
plt.show()
# Out:
# độ dài X: 100
# độ dài X_train: 80
# Test MAE: 0.0011625289916992188
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x14a79afc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
